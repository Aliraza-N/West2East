# %%
import os
os.getcwd()

os.chdir('C://Users//Amardeep//Downloads//parking_tags_data_2020')

import os
import glob
import pandas as pd
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

all_filenames

#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# !pip install fuzzywuzzy

from fuzzywuzzy import process, fuzz


hr = pd.read_csv('combined_csv.csv')
it = pd.read_csv('tsv.csv')

hr.columns

it.columns

# !pip install fuzzy_pandas

import pandas as pd
import fuzzy_pandas as fpd
results = fpd.fuzzy_merge(hr, it,
            left_on= 'location2',
            right_on=' Side 1 Route ',
            method='levenshtein',
            threshold=0.50,
            keep='match')

print("Found", results.shape)
results.head(10)

df

df = pd.read_csv('tsv.csv')


df.dtypes

df['date_of_infraction']= pd.to_datetime(df['date_of_infraction'])

df['Count Date'] = df['Count Date'].str.replace('*', '').str.replace(',', '')

df['Latitude'] = df['Latitude'].str.replace('*', '').str.replace(',', '')

df['Longitude'] = df['Longitude'].str.replace('*', '').str.replace(',', '')

df['Longitude'] = df['Longitude'].str.replace('*', '').str.replace(',', '')

df['8 Peak Hr Vehicle Volume'] = df['8 Peak Hr Vehicle Volume'].str.replace('*', '').str.replace(',', '')
df['8 Peak Hr Pedestrian Volume'] = df['8 Peak Hr Pedestrian Volume'].str.replace('*', '').str.replace(',', '')
df['Activation Date'] = df['Activation Date'].str.replace('*', '').str.replace(',', '')
df['TCS '] = df['TCS '].str.replace('*', '').str.replace(',', '')

df['Count Date']= pd.to_datetime(df['Count Date'])

df['Activation Date']= pd.to_datetime(df['Activation Date'])

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('tsv.csv')

# %%
df['date_of_infraction']= pd.to_datetime(df['date_of_infraction'])

df['Count Date'] = df['Count Date'].str.replace('*', '').str.replace(',', '')

df['Latitude'] = df['Latitude'].str.replace('*', '').str.replace(',', '')

df['Longitude'] = df['Longitude'].str.replace('*', '').str.replace(',', '')

df['Longitude'] = df['Longitude'].str.replace('*', '').str.replace(',', '')

df['8 Peak Hr Vehicle Volume'] = df['8 Peak Hr Vehicle Volume'].str.replace('*', '').str.replace(',', '')
df['8 Peak Hr Pedestrian Volume'] = df['8 Peak Hr Pedestrian Volume'].str.replace('*', '').str.replace(',', '')
df['Activation Date'] = df['Activation Date'].str.replace('*', '').str.replace(',', '')
df['TCS '] = df['TCS '].str.replace('*', '').str.replace(',', '')

df['Count Date']= pd.to_datetime(df['Count Date'])

df['Activation Date']= pd.to_datetime(df['Activation Date'])

# %%
df
# Out:
#        tag_number_masked            date_of_infraction  infraction_code  \
# 0               ***60020 1970-01-01 00:00:00.020200101                3
# 1               ***46473 1970-01-01 00:00:00.020200101               29
# 2               ***46474 1970-01-01 00:00:00.020200101               29
# 3               ***46475 1970-01-01 00:00:00.020200101               29
# 4               ***46674 1970-01-01 00:00:00.020200101               29
# ...                  ...                           ...              ...
# 955192          ***59676 1970-01-01 00:00:00.020201014              207
# 955193          ***60684 1970-01-01 00:00:00.020201014                9
# 955194          ***76174 1970-01-01 00:00:00.020201014                5
# 955195          ***95621 1970-01-01 00:00:00.020201014              423
# 955196          ***99064 1970-01-01 00:00:00.020201014                9
#
#                 infraction_description  set_fine_amount  time_of_infraction  \
# 0             PARK ON PRIVATE PROPERTY               30                 1.0
# 1       PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 2       PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 3       PARK PROHIBITED TIME NO PERMIT               30                 4.0
# 4       PARK PROHIBITED TIME NO PERMIT               30                 4.0
# ...                                ...              ...                 ...
# 955192  PARK MACHINE-REQD FEE NOT PAID               30              1342.0
# 955193  STOP-SIGNED HWY-PROHIBIT TM/DY              100              1342.0
# 955194  PARK-SIGNED HWY-PROHIBIT DY/TM               50              1342.0
# 955195  STOP VEH.RESRVD/DESIG LN TM/DY              150              1342.0
# 955196  STOP-SIGNED HWY-PROHIBIT TM/DY              100              1342.0
#
#        location1          location2 location3 location4 province  \
# 0            NaN       4700 JANE ST       NaN       NaN       SK
# 1            OPP  573 CLENDENAN AVE       NaN       NaN       ON
# 2             NR  573 CLENDENAN AVE       NaN       NaN       ON
# 3             NR        21 MARIA ST       NaN       NaN       ON
# 4             NR  164 GLENHOLME AVE       NaN       NaN       ON
# ...          ...                ...       ...       ...      ...
# 955192        NR     36 VICTORIA ST       NaN       NaN       ON
# 955193        NR    251 SPADINA AVE       NaN       NaN       ON
# 955194       S/S    WELLINGTON ST E       E/O  YONGE ST       ON
# 955195        NR         955 BAY ST       NaN       NaN       ON
# 955196       N/S          EDWARD ST       E/O    BAY ST       ON
#
#             Latitude      Longitude Count Date 8 Peak Hr Vehicle Volume  \
# 0       43.818186976  -79.173580043 2009-07-26                     1982
# 1       43.818186976  -79.173580043 2009-07-26                     1982
# 2       43.818186976  -79.173580043 2009-07-26                     1982
# 3           43.73338      -79.24867 2016-05-26                    10664
# 4         43.7905795    -79.2699662 2016-12-15                    13883
# ...              ...            ...        ...                      ...
# 955192   43.81818698  -79.173580043 2009-07-26                     1982
# 955193   43.63661608  -79.396928931 2012-02-22                     5781
# 955194   43.81818698  -79.173580043 2009-07-26                     1982
# 955195   43.81818698  -79.173580043 2009-07-26                     1982
# 955196   43.81818698  -79.173580043 2009-07-26                     1982
#
#        8 Peak Hr Pedestrian Volume Activation Date  TCS
# 0                               16      1974-02-08  3014
# 1                               16      1974-02-08  3014
# 2                               16      1974-02-08  3014
# 3                              253      2007-06-07  2099
# 4                               72      1992-10-07  1639
# ...                            ...             ...   ...
# 955192                          16      1974-02-08  3014
# 955193                        1156      2000-07-14  2417
# 955194                          16      1974-02-08  3014
# 955195                          16      1974-02-08  3014
# 955196                          16      1974-02-08  3014
#
# [955197 rows x 18 columns]

# %%
df1 = df[['date_of_infraction','set_fine_amount','time_of_infraction','location2','Latitude','Longitude','Count Date','8 Peak Hr Vehicle Volume','8 Peak Hr Pedestrian Volume']]

# %%
df1
# Out:
#                   date_of_infraction  set_fine_amount  time_of_infraction  \
# 0      1970-01-01 00:00:00.020200101               30                 1.0
# 1      1970-01-01 00:00:00.020200101               30                 2.0
# 2      1970-01-01 00:00:00.020200101               30                 2.0
# 3      1970-01-01 00:00:00.020200101               30                 4.0
# 4      1970-01-01 00:00:00.020200101               30                 4.0
# ...                              ...              ...                 ...
# 955192 1970-01-01 00:00:00.020201014               30              1342.0
# 955193 1970-01-01 00:00:00.020201014              100              1342.0
# 955194 1970-01-01 00:00:00.020201014               50              1342.0
# 955195 1970-01-01 00:00:00.020201014              150              1342.0
# 955196 1970-01-01 00:00:00.020201014              100              1342.0
#
#                 location2      Latitude      Longitude Count Date  \
# 0            4700 JANE ST  43.818186976  -79.173580043 2009-07-26
# 1       573 CLENDENAN AVE  43.818186976  -79.173580043 2009-07-26
# 2       573 CLENDENAN AVE  43.818186976  -79.173580043 2009-07-26
# 3             21 MARIA ST      43.73338      -79.24867 2016-05-26
# 4       164 GLENHOLME AVE    43.7905795    -79.2699662 2016-12-15
# ...                   ...           ...            ...        ...
# 955192     36 VICTORIA ST   43.81818698  -79.173580043 2009-07-26
# 955193    251 SPADINA AVE   43.63661608  -79.396928931 2012-02-22
# 955194    WELLINGTON ST E   43.81818698  -79.173580043 2009-07-26
# 955195         955 BAY ST   43.81818698  -79.173580043 2009-07-26
# 955196          EDWARD ST   43.81818698  -79.173580043 2009-07-26
#
#        8 Peak Hr Vehicle Volume 8 Peak Hr Pedestrian Volume  \
# 0                          1982                          16
# 1                          1982                          16
# 2                          1982                          16
# 3                         10664                         253
# 4                         13883                          72
# ...                         ...                         ...
# 955192                     1982                          16
# 955193                     5781                        1156
# 955194                     1982                          16
# 955195                     1982                          16
# 955196                     1982                          16
#
#         date_of_infraction_year  date_of_infraction_month  \
# 0                          1970                         1
# 1                          1970                         1
# 2                          1970                         1
# 3                          1970                         1
# 4                          1970                         1
# ...                         ...                       ...
# 955192                     1970                         1
# 955193                     1970                         1
# 955194                     1970                         1
# 955195                     1970                         1
# 955196                     1970                         1
#
#         date_of_infraction_week  date_of_infraction_day  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             1                       1
# ...                         ...                     ...
# 955192                        1                       1
# 955193                        1                       1
# 955194                        1                       1
# 955195                        1                       1
# 955196                        1                       1
#
#         date_of_infraction_dayofweek  Count Date_year  Count Date_month  \
# 0                                  3             2009                 7
# 1                                  3             2009                 7
# 2                                  3             2009                 7
# 3                                  3             2016                 5
# 4                                  3             2016                12
# ...                              ...              ...               ...
# 955192                             3             2009                 7
# 955193                             3             2012                 2
# 955194                             3             2009                 7
# 955195                             3             2009                 7
# 955196                             3             2009                 7
#
#         Count Date_week  Count Date_day  Count Date_dayofweek
# 0                    30              26                     6
# 1                    30              26                     6
# 2                    30              26                     6
# 3                    21              26                     3
# 4                    50              15                     3
# ...                 ...             ...                   ...
# 955192               30              26                     6
# 955193                8              22                     2
# 955194               30              26                     6
# 955195               30              26                     6
# 955196               30              26                     6
#
# [955197 rows x 19 columns]

# %%
df1['date_of_infraction_year'] = df1['date_of_infraction'].dt.year
df1['date_of_infraction_month'] = df1['date_of_infraction'].dt.month
df1['date_of_infraction_week'] = df1['date_of_infraction'].dt.week
df1['date_of_infraction_day'] = df1['date_of_infraction'].dt.day
df1['date_of_infraction_dayofweek'] = df1['date_of_infraction'].dt.dayofweek
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   app.launch_new_instance()
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1['Count Date_year'] = df1['Count Date'].dt.year
df1['Count Date_month'] = df1['Count Date'].dt.month
df1['Count Date_week'] = df1['Count Date'].dt.week
df1['Count Date_day'] = df1['Count Date'].dt.day
df1['Count Date_dayofweek'] = df1['Count Date'].dt.dayofweek
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   app.launch_new_instance()
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
df1 = df1.drop('date_of_infraction',axis = 1)
df1 = df1.drop('Count Date',axis = 1)
df1 = df1.drop('location2',axis = 1)

# %%
df1 = df1.dropna(how='all')

# %%
df1
# Out:
# 0            1
# 1            2
# 2            2
# 3            4
# 4            4
#           ...
# 955192    1342
# 955193    1342
# 955194    1342
# 955195    1342
# 955196    1342
# Name: time_of_infraction, Length: 955197, dtype: Int64

# %%
one_hot=pd.get_dummies(df1['location2'])
# Drop column as it is now encoded
df1 = df1.drop('location2',axis = 1)
# Join the encoded df
df1 = df1.join(one_hot)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-16-392e5ee82148> in <module>
# ----> 1 one_hot=pd.get_dummies(df1['location2'])
#       2 # Drop column as it is now encoded
#       3 df1 = df1.drop('location2',axis = 1)
#       4 # Join the encoded df
#       5 df1 = df1.join(one_hot)
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     906             sparse=sparse,
#     907             drop_first=drop_first,
# --> 908             dtype=dtype,
#     909         )
#     910     return result
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#    1003
#    1004     else:
# -> 1005         dummy_mat = np.eye(number_of_cols, dtype=dtype).take(codes, axis=0)
#    1006
#    1007         if not dummy_na:
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/numpy/lib/twodim_base.py in eye(N, M, k, dtype, order)
#     197     if M is None:
#     198         M = N
# --> 199     m = zeros((N, M), dtype=dtype, order=order)
#     200     if k >= M:
#     201         return m
#
# MemoryError: Unable to allocate 15.1 GiB for an array with shape (127353, 127353) and data type uint8

# %%
# check scikit-learn version
import sklearn
print(sklearn.__version__)
# Out:
# 0.24.1

# %%
df1.time_of_infraction.round().astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-df547fc46729> in <module>
# ----> 1 df1.time_of_infraction.round().astype(np.int64)
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     407                 applied = b.apply(f, **kwargs)
#     408             else:
# --> 409                 applied = getattr(b, f)(**kwargs)
#     410             result_blocks = _extend_blocks(applied, result_blocks)
#     411
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     593             vals1d = values.ravel()
#     594             try:
# --> 595                 values = astype_nansafe(vals1d, dtype, copy=True)
#     596             except (ValueError, TypeError):
#     597                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     966
#     967         if not np.isfinite(arr).all():
# --> 968             raise ValueError("Cannot convert non-finite values (NA or inf) to integer")
#     969
#     970     elif is_object_dtype(arr):
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
import pandas as pd

def clean_dataset(df1):
    assert isinstance(df1, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
df1['time_of_infraction'].astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-c3ac9c259704> in <module>
# ----> 1 df1['time_of_infraction'].astype(np.int64)
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     407                 applied = b.apply(f, **kwargs)
#     408             else:
# --> 409                 applied = getattr(b, f)(**kwargs)
#     410             result_blocks = _extend_blocks(applied, result_blocks)
#     411
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     593             vals1d = values.ravel()
#     594             try:
# --> 595                 values = astype_nansafe(vals1d, dtype, copy=True)
#     596             except (ValueError, TypeError):
#     597                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     966
#     967         if not np.isfinite(arr).all():
# --> 968             raise ValueError("Cannot convert non-finite values (NA or inf) to integer")
#     969
#     970     elif is_object_dtype(arr):
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
df1.columns
# Out:
# Index(['set_fine_amount', 'time_of_infraction', 'Latitude', 'Longitude',
#        '8 Peak Hr Vehicle Volume', '8 Peak Hr Pedestrian Volume',
#        'date_of_infraction_year', 'date_of_infraction_month',
#        'date_of_infraction_week', 'date_of_infraction_day',
#        'date_of_infraction_dayofweek', 'Count Date_year', 'Count Date_month',
#        'Count Date_week', 'Count Date_day', 'Count Date_dayofweek'],
#       dtype='object')

# %%
X=df1.drop(columns=['8 Peak Hr Vehicle Volume','8 Peak Hr Pedestrian Volume'])

# %%
y= df1[['8 Peak Hr Vehicle Volume','8 Peak Hr Pedestrian Volume']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.60)

# %%
# linear regression for multioutput regression
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
# create datasets
# define model
model = LinearRegression()
# fit model
#Splitting the input and output into separate dataframes
model.fit(X_train, y_train)
# prediction on test set
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([[ 2331.41369184,   -68.21245834],
#        [12059.57830774,  1337.55255758],
#        [ 2314.36471613,   -66.17355986],
#        ...,
#        [ 9165.16765056,   596.66869624],
#        [11583.56338672,  1028.88546278],
#        [ 2317.0896907 ,   -64.76285746]])

# %%
# k-nearest neighbors for multioutput regression
from sklearn.datasets import make_regression
from sklearn.neighbors import KNeighborsRegressor
# create datasets
model1 = KNeighborsRegressor()
# fit model
model1.fit(X_train, y_train)
# make a prediction
y_pred1=model1.predict(X_test)
# summarize prediction
print(y_pred1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-85-71cdee97eea8> in <module>
#       7 model1.fit(X_train, y_train)
#       8 # make a prediction
# ----> 9 y_pred1=model1.predict(X_test)
#      10 # summarize prediction
#      11 print(y_pred1)
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sklearn/neighbors/_regression.py in predict(self, X)
#     206         X = check_array(X, accept_sparse='csr')
#     207
# --> 208         neigh_dist, neigh_ind = self.kneighbors(X)
#     209
#     210         weights = _get_weights(neigh_dist, self.weights)
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     706                 X, self._fit_X, reduce_func=reduce_func,
#     707                 metric=self.effective_metric_, n_jobs=n_jobs,
# --> 708                 **kwds))
#     709
#     710         elif self._fit_method in ['ball_tree', 'kd_tree']:
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1622             X_chunk = X[sl]
#    1623         D_chunk = pairwise_distances(X_chunk, Y, metric=metric,
# -> 1624                                      n_jobs=n_jobs, **kwds)
#    1625         if ((X is Y or Y is None)
#    1626                 and PAIRWISE_DISTANCE_FUNCTIONS.get(metric, None)
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1788         func = partial(distance.cdist, metric=metric, **kwds)
#    1789
# -> 1790     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1791
#    1792
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1357
#    1358     if effective_n_jobs(n_jobs) == 1:
# -> 1359         return func(X, Y, **kwds)
#    1360
#    1361     # enforce a threading backend to prevent data communication overhead
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     311     else:
#     312         # if dtype is already float64, no need to chunk and upcast
# --> 313         distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     314         distances += XX
#     315         distances += YY
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     150             ret = np.dot(a, b)
#     151     else:
# --> 152         ret = a @ b
#     153
#     154     if (sparse.issparse(a) and sparse.issparse(b)
#
# MemoryError: Unable to allocate 1022. MiB for an array with shape (351, 381747) and data type float64

# %%
df1.dtypes
# Out:
# set_fine_amount                   int64
# time_of_infraction              float64
# Latitude                        float64
# Longitude                       float64
# 8 Peak Hr Vehicle Volume          int64
# 8 Peak Hr Pedestrian Volume       int64
# date_of_infraction_year           int64
# date_of_infraction_month          int64
# date_of_infraction_week           int64
# date_of_infraction_day            int64
# date_of_infraction_dayofweek      int64
# Count Date_year                   int64
# Count Date_month                  int64
# Count Date_week                   int64
# Count Date_day                    int64
# Count Date_dayofweek              int64
# hour_sin                        float64
# hour_cos                        float64
# dtype: object

# %%
df1["8 Peak Hr Vehicle Volume"] = df1["8 Peak Hr Vehicle Volume"].astype(str).astype(int)

# %%
df1["8 Peak Hr Pedestrian Volume"] = df1["8 Peak Hr Pedestrian Volume"].astype(str).astype(int)

# %%
df1['hour_sin'] = np.sin(2 * np.pi * df1['time_of_infraction']/23.0)

# %%
df1['hour_cos'] = np.cos(2 * np.pi * df1['time_of_infraction']/23.0)

# %%
df1["Latitude"] = df1.Latitude.astype(float)

# %%
df1["Longitude"] = df1.Latitude.astype(float)

# %%
np.where(df1.values >= np.finfo(np.float64).max)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
pd.isnull(df1).sum() > 0
# Out:
# set_fine_amount                 False
# time_of_infraction              False
# Latitude                        False
# Longitude                       False
# 8 Peak Hr Vehicle Volume        False
# 8 Peak Hr Pedestrian Volume     False
# date_of_infraction_year         False
# date_of_infraction_month        False
# date_of_infraction_week         False
# date_of_infraction_day          False
# date_of_infraction_dayofweek    False
# Count Date_year                 False
# Count Date_month                False
# Count Date_week                 False
# Count Date_day                  False
# Count Date_dayofweek            False
# hour_sin                        False
# hour_cos                        False
# dtype: bool

# %%
df1 = df1.dropna()
